# %% [markdown]
# # Create LoadData CSVs with the paths to IC functions for analysis
#
# In this notebook, we create LoadData CSVs that contains paths to each channel per image set and associated illumination correction `npy` files per channel for CellProfiler to process.

# %% [markdown]
# ## Import libraries

# %%
import argparse
import pathlib
import pandas as pd
import re
import os

import sys

sys.path.append("../../utils")
import loaddata_utils as ld_utils
from bandicoot_utils import bandicoot_check

# %% [markdown]
# ## Set paths

# %%
argparse = argparse.ArgumentParser(
    description="Create LoadData CSV files to run CellProfiler on the cluster"
)
argparse.add_argument("--HPC", action="store_true", help="Type of compute to run on")

# Parse arguments
args = argparse.parse_args(args=sys.argv[1:] if "ipykernel" not in sys.argv[0] else [])
HPC = args.HPC

print(f"HPC: {HPC}")
# Out:
# HPC: False

# %%
# Set the index directory based on whether HPC is used or not
if HPC:
    # Path for index directory to make loaddata csvs though compute cluster (HPC)
    index_directory = pathlib.Path(
        "/scratch/alpine/jtomkinson@xsede.org/ALSF_screen_data/SK-N-AS_repo1_screen"
    )
else:
    # Find root directory of the project
    root_dir = pathlib.Path().resolve()

    image_base_dir = bandicoot_check(
        pathlib.Path(os.path.expanduser("~/mnt/bandicoot")).resolve(), root_dir
    )
    # Path for index directory  to make loaddata csv locally
    index_directory = pathlib.Path(
        f"{image_base_dir}/PCCMA_data/SK-N-AS_repo1_screen/"
    ).resolve(strict=True)

# Set all paths that are common to both HPC and local
config_dir_path = pathlib.Path("../1.illumination_correction/load_data_config/").resolve(
    strict=True
)
output_csv_dir = pathlib.Path("./loaddata_csvs/").absolute()
output_csv_dir.mkdir(parents=True, exist_ok=True)
illum_directory = pathlib.Path("../1.illumination_correction/illum_directory/").resolve(
    strict=True
)

# Find all 'Images' folders within the directory
images_folders = list(index_directory.rglob("Images"))
print(f"Found {len(images_folders)} 'Images' folders in the directory.")
# Out:
# Found 48 'Images' folders in the directory.

# %% [markdown]
# ## Create LoadData CSVs with illumination functions for all data

# %%
config_path = pathlib.Path(config_dir_path / "config.yml").resolve(strict=True)

csv_paths = []

for top_level in index_directory.iterdir():
    if not top_level.is_dir():
        continue

    print(f"\nProcessing: {top_level.name}")

    is_screen = "Screen" in top_level.name
    is_row_o_repeat = "Row O Repeat" in top_level.name

    for subfolder in top_level.iterdir():
        if not subfolder.is_dir():
            continue

        br_id = subfolder.name.split("__")[0]

        match = re.search(r"(BR\d+)", br_id)
        if not match:
            print(f"Skipping {subfolder} (no BR ID found)")
            continue

        plate_id = match.group(1)

        print(f"  Processing plate: {plate_id}")

        # Output paths (function writes to BOTH)
        path_to_output_csv = (
            output_csv_dir / f"{plate_id}_loaddata_original.csv"
        ).absolute()

        path_to_output_with_illum_csv = (
            output_csv_dir / f"{plate_id}_loaddata_with_illum.csv"
        ).absolute()

        illum_output_path = (
            (illum_directory / plate_id).absolute().resolve(strict=True)
        )

        # Run loaddata (function handles writing both outputs)
        ld_utils.create_loaddata_illum_csv(
            index_directory=subfolder / "Images",
            config_path=config_path,
            path_to_output=path_to_output_csv,
            illum_directory=illum_output_path,
            plate_id=plate_id,
            illum_output_path=path_to_output_with_illum_csv,
        )

        # ---- Row O filtering ONLY for Screen plates ----
        df = pd.read_csv(path_to_output_csv)

        if is_screen:
            df_filtered = df[~df["Well"].astype(str).str.startswith("O")]

            assert len(df_filtered) < len(df), (
                f"{plate_id} (Screen) expected Row O wells to be removed."
            )

            assert not df_filtered["Well"].astype(str).str.startswith("O").any(), (
                f"{plate_id} (Screen) still contains Row O wells."
            )

            df_filtered.to_csv(path_to_output_with_illum_csv, index=False)

        elif is_row_o_repeat:
            assert df["Well"].astype(str).str.startswith("O").any(), (
                f"{plate_id} (Row O Repeat) missing Row O wells."
            )

        print(f"  Created LoadData CSVs for {plate_id}")

        csv_paths.append(path_to_output_with_illum_csv)

# ---- Final sanity check ----
unique_plates = {p.stem.split("_")[0] for p in csv_paths}

print(f"\nTotal plates processed: {len(unique_plates)}")

if len(unique_plates) != 29:
    raise ValueError(f"Expected 29 plates, but got {len(unique_plates)}")

print("All LoadData CSVs with illumination created successfully!")
# Out:
# Processing top-level folder: Atlas_SKNAS-1020_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_SKNAS-1020_
# BR00149123_Atlas_SKNAS-1020__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_SKNAS-1020__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_SKNAS-1020__Reimage
# BR00149120_Atlas_SKNAS-1020__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_SKNAS-1020__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_SKNAS-1020__Reimage
# BR00149121_Atlas_SKNAS-1020__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_SKNAS-1020__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_SKNAS-1020__Reimage
#
# Processing top-level folder: Atlas_G401_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_G401_
# BR00149123_Atlas_G401__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_G401__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_G401__Reimage
# BR00149120_Atlas_G401__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_G401__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_G401__Reimage
# BR00149121_Atlas_G401__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_G401__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_G401__Reimage
#
# Processing top-level folder: Atlas_D283_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_D283_
# BR00149120_Atlas_D283__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_D283__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_D283__Reimage
# BR00149121_Atlas_D283__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_D283__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_D283__Reimage
# BR00149123_Atlas_D283__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_D283__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_D283__Reimage
#
# Processing top-level folder: Atlas_SKNAS_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_SKNAS_
# BR00149120_Atlas_SKNAS__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_SKNAS__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_SKNAS__Reimage
# BR00149123_Atlas_SKNAS__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_SKNAS__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_SKNAS__Reimage
# BR00149121_Atlas_SKNAS__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_SKNAS__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_SKNAS__Reimage
#
# Processing top-level folder: Atlas_CHP212-1020_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_CHP212-1020_
# BR00149123_Atlas_CHP212-1020__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_CHP212-1020__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_CHP212-1020__Reimage
# BR00149120_Atlas_CHP212-1020__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_CHP212-1020__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_CHP212-1020__Reimage
# BR00149121_Atlas_CHP212-1020__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_CHP212-1020__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_CHP212-1020__Reimage
#
# Processing top-level folder: Atlas_SKNDZ_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_SKNDZ_
# BR00149120_Atlas_SKNDZ__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_SKNDZ__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_SKNDZ__Reimage
# BR00149121_Atlas_SKNDZ__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_SKNDZ__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_SKNDZ__Reimage
# BR00149123_Atlas_SKNDZ__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_SKNDZ__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_SKNDZ__Reimage
#
# Processing top-level folder: Atlas_SH-SY5Y_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_SH-SY5Y_
# BR00149120_Atlas_SH-SY5Y__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_SH-SY5Y__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_SH-SY5Y__Reimage
# BR00149123_Atlas_SH-SY5Y__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_SH-SY5Y__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_SH-SY5Y__Reimage
# BR00149121_Atlas_SH-SY5Y__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_SH-SY5Y__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_SH-SY5Y__Reimage
#
# Processing top-level folder: Atlas_CHLA-218_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_CHLA-218_
# BR00149121_Atlas_CHLA-218__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_CHLA-218__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_CHLA-218__Reimage
# BR00149123_Atlas_CHLA-218__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_CHLA-218__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_CHLA-218__Reimage
# BR00149120_Atlas_CHLA-218__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_CHLA-218__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_CHLA-218__Reimage
#
# Processing top-level folder: Atlas_G292cloneA141B1_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_G292cloneA141B1_
# BR00149121_Atlas_G292cloneA141B1__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_G292cloneA141B1__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_G292cloneA141B1__Reimage
# BR00149120_Atlas_G292cloneA141B1__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_G292cloneA141B1__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_G292cloneA141B1__Reimage
# BR00149123_Atlas_G292cloneA141B1__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_G292cloneA141B1__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_G292cloneA141B1__Reimage
#
# Processing top-level folder: Atlas_NB1_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_NB1_
# BR00149120_Atlas_NB1__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_NB1__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_NB1__Reimage
# BR00149123_Atlas_NB1__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_NB1__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_NB1__Reimage
# BR00149121_Atlas_NB1__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_NB1__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_NB1__Reimage
#
# Processing top-level folder: Atlas_CHLA-113_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_CHLA-113_
# BR00149120_Atlas_CHLA-113__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_CHLA-113__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_CHLA-113__Reimage
# BR00149123_Atlas_CHLA-113__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_CHLA-113__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_CHLA-113__Reimage
# BR00149121_Atlas_CHLA-113__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_CHLA-113__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_CHLA-113__Reimage
#
# Processing top-level folder: All Cell Lines
#   Detected as original run (All Cell Lines)
# BR00149123_loaddata_with_illum.csv is created!
# The BR00149123_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123
# BR00149120_loaddata_with_illum.csv is created!
# The BR00149120_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120
# BR00149121_loaddata_with_illum.csv is created!
# The BR00149121_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121
#
# Processing top-level folder: Atlas_KNS42_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_KNS42_
# BR00149121_Atlas_KNS42__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_KNS42__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_KNS42__Reimage
# BR00149120_Atlas_KNS42__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_KNS42__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_KNS42__Reimage
# BR00149123_Atlas_KNS42__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_KNS42__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_KNS42__Reimage
#
# Processing top-level folder: Atlas_CHP-134_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_CHP-134_
# BR00149123_Atlas_CHP-134__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_CHP-134__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_CHP-134__Reimage
# BR00149120_Atlas_CHP-134__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_CHP-134__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_CHP-134__Reimage
# BR00149121_Atlas_CHP-134__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_CHP-134__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_CHP-134__Reimage
#
# Processing top-level folder: Atlas_A673_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_A673_
# BR00149121_Atlas_A673__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_A673__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_A673__Reimage
# BR00149120_Atlas_A673__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_A673__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_A673__Reimage
# BR00149123_Atlas_A673__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_A673__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_A673__Reimage
#
# Processing top-level folder: Atlas_CHP212_reimage
#   Detected as reimaged folder
#   Reimaged cell line identifier: Atlas_CHP212_
# BR00149120_Atlas_CHP212__Reimage_loaddata_with_illum.csv is created!
# The BR00149120_Atlas_CHP212__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149120_Atlas_CHP212__Reimage
# BR00149123_Atlas_CHP212__Reimage_loaddata_with_illum.csv is created!
# The BR00149123_Atlas_CHP212__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149123_Atlas_CHP212__Reimage
# BR00149121_Atlas_CHP212__Reimage_loaddata_with_illum.csv is created!
# The BR00149121_Atlas_CHP212__Reimage_loaddata_original.csv CSV file has been removed as it does not contain the IC functions.
# Created LoadData CSV with illumination for BR00149121_Atlas_CHP212__Reimage
