# %% [markdown]
# # Convert original Excel platemap file to individual CSVs per plate

# %%
from pathlib import Path

import pandas as pd

# %%
# Define paths
xlsx_folder = Path("orig_xlsx_files")
metadata_folder = Path("metadata")
metadata_folder.mkdir(exist_ok=True)  # Ensure metadata folder exists

# Initialize a list to store barcode and file mapping
barcode_platemap = []

# Iterate through all xlsx files in the folder
for xlsx_file in xlsx_folder.glob("*.xlsx"):
    # Read the Excel file
    df = pd.read_excel(xlsx_file)

    # Normalize column names
    df.columns = [col.replace("(", "").replace(")", "").replace(" ", "_") for col in df.columns]

    # Identify unique plates in 'Plate_Barcode' column
    unique_plates = df["Plate_Barcode"].unique()
    print(f"Processing {xlsx_file.name}: Found {len(unique_plates)} unique plates.")

    # Split into individual CSV files per unique plate
    for plate in unique_plates:
        plate_df = df[df["Plate_Barcode"] == plate]
        output_file = metadata_folder / f"{plate}_platemap.csv"
        plate_df.to_csv(output_file, index=False)
        print(f"Saved {output_file}")

        # Append barcode and file name to the list
        barcode_platemap.append({"Plate_Barcode": plate, "File_Name": output_file.name})
# Out:
# Processing SK-N-AS_REPO1_PlateMaps_20251212.xlsx: Found 27 unique plates.
# Saved metadata/BR00148919_platemap.csv
# Saved metadata/BR00148920_platemap.csv
# Saved metadata/BR00148921_platemap.csv
# Saved metadata/BR00148922_platemap.csv
# Saved metadata/BR00148923_platemap.csv
# Saved metadata/BR00148924_platemap.csv
# Saved metadata/BR00148925_platemap.csv
# Saved metadata/BR00148926_platemap.csv
# Saved metadata/BR00148927_platemap.csv
# Saved metadata/BR00148928_platemap.csv
# Saved metadata/BR00148929_platemap.csv
# Saved metadata/BR00148930_platemap.csv
# Saved metadata/BR00148931_platemap.csv
# Saved metadata/BR00148932_platemap.csv
# Saved metadata/BR00148933_platemap.csv
# Saved metadata/BR00148934_platemap.csv
# Saved metadata/BR00148935_platemap.csv
# Saved metadata/BR00148936_platemap.csv
# Saved metadata/BR00148937_platemap.csv
# Saved metadata/BR00148938_platemap.csv
# Saved metadata/BR00148939_platemap.csv
# Saved metadata/BR00148940_platemap.csv
# Saved metadata/BR00148941_platemap.csv
# Saved metadata/BR00148942_platemap.csv
# Saved metadata/BR00148943_platemap.csv
# Saved metadata/BR00148944_platemap.csv
# Saved metadata/BR00148945_platemap.csv
# Processing SKNAS_REPO1_RowO_repeat.xlsx: Found 2 unique plates.
# Saved metadata/BR00149048_platemap.csv
# Saved metadata/BR00149049_platemap.csv

# %%
# Create a DataFrame for barcode and file mapping
barcode_platemap_df = pd.DataFrame(barcode_platemap)
barcode_platemap_file = metadata_folder / "barcode_platemap.csv"
barcode_platemap_df.to_csv(barcode_platemap_file, index=False)
print(f"Saved barcode mapping file: {barcode_platemap_file}")
# Out:
# Saved barcode mapping file: metadata/barcode_platemap.csv
